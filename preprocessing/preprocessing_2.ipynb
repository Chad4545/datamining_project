# %%
rm(list=ls())
getwd()
dir='/Users/sungjinpark/OneDrive - konkuk.ac.kr/datamining/appstore_2/1preprocessing'
setwd(dir)
load('game_nongame.rda')
load('game_etc.rda')
library(ggplot2)
library(scales)
# Out:
# [1] "/Users/sungjinpark/OneDrive - konkuk.ac.kr/datamining/appstore_2/1preprocessing"

# %%
unique(new_data1$prime_genre)
unique(new_data2$prime_genre)
# Out:
# [1] Games     Non_Games
# Levels: Games Non_Games
# [1] Games         etc           Utilities     Entertainment Photo & Video
# [6] Education
# Levels: Education Entertainment Games Photo & Video Utilities etc

# %% [markdown]
# ## 3. Continuous 변수 전처리

# %% [markdown]
# #### 3.1 size_bytes -> size_mega
#
# #### min : 0.5625
# #### max: 3839.4638671875

# %%
#size : byte -> megabyte
new_data1['size_mega'] = new_data1['size_bytes'] / (1024 * 1024.0)
new_data2['size_mega'] = new_data2['size_bytes'] / (1024 * 1024.0)
drops <- c("size_bytes")
new_data1=new_data1[ , !(names(new_data1) %in% drops)]
new_data2=new_data2[ , !(names(new_data2) %in% drops)]
#min(new_data1$size_mega)
#max(new_data1$size_mega)

# %%
ggplot(new_data1, aes(x = (size_mega),
                      fill = size_mega)) +
  geom_density(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="size_mega", 
       
       caption="Source: App store 7200 (2017)",
       x="size_mega",y = 'Percent',
       fill="size_mega")
# Out:
# plot without title

# %% [markdown]
# ### 3.2  sup_devices.num ( 지원가능 디바이스 수)
#
#
# #### min : 9
#
# #### max: 47

# %%
#sup_devices.num
unique(new_data1$sup_devices.num)
#min(new_data1$sup_devices.num)
#max(new_data1$sup_devices.num)
# Out:
#  [1] 38 37 47 43 40 12 45 24 26 39 35 25 16 11 36 23 15 13 33  9

# %%
ggplot(new_data1, aes(x = (sup_devices.num),
                      fill = sup_devices.num)) +
  geom_density(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="sup_devices.num", 
       
       caption="Source: App store 7200 (2017)",
       x="sup_devices.num",y = 'Percent',
       fill="sup_devices.num")
# Out:
# plot without title

# %%
ggplot(new_data1, aes(x = factor(sup_devices.num),
                      fill = factor(sup_devices.num))) +
  geom_bar(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="sup_devices.num", 
       
       caption="Source: App store 7200 (2017)",
       x="sup_devices.num",y = 'Percent',
       fill="sup_devices.num")
# Out:
# plot without title

# %% [markdown]
# ### 3.3  ipadSc_urls.num ( 설명 스크린샷 수)
#
#
# #### min : 0
#
# #### max: 5

# %%
#ipadSC
#unique(new_data1$ipadSc_urls.num)
#min(new_data1$ipadSc_urls.num)
#max(new_data1$ipadSc_urls.num)

# %%
ggplot(new_data1, aes(x = (ipadSc_urls.num),
                      fill = ipadSc_urls.num)) +
  geom_density(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="ipadSc_urls.num", 
       
       caption="Source: App store 7200 (2017)",
       x="ipadSc_urls.num",y = 'Percent',
       fill="ipadSc_urls.num")
# Out:
# plot without title

# %%
ggplot(new_data1, aes(x = factor(ipadSc_urls.num),
                      fill = factor(ipadSc_urls.num))) +
  geom_bar(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="ipadSc_urls.num", 
       
       caption="Source: App store 7200 (2017)",
       x="ipadSc_urls.num",y = 'Percent',
       fill="ipadSc_urls.num")
# Out:
# plot without title

# %% [markdown]
# ### 3.4  lang.num ( 지원 언어 수)
#
#
# #### min : 0
#
# #### max: 75

# %%
#lang.num
#unique(new_data1$lang.num)
#min(new_data1$lang.num)
#max(new_data1$lang.num)

# %%
ggplot(new_data1, aes(x = (lang.num),
                      fill = lang.num)) +
  geom_density(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="lang.num", 
       
       caption="Source: App store 7200 (2017)",
       x="lang.num",y = 'Percent',
       fill="lang.num")
# Out:
# plot without title

# %%
ggplot(new_data1, aes(x = factor(lang.num),
                      fill = factor(lang.num))) +
  geom_bar(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="lang.num", 
       
       caption="Source: App store 7200 (2017)",
       x="lang.num",y = 'Percent',
       fill="lang.num")
# Out:
# plot without title

# %% [markdown]
# ### 3.5 Price
#
#
# #### min : 0
#
# #### max: 299.99

# %%
# price    
#min(new_data1$price)
#max(new_data1$price)

# %%
ggplot(new_data1, aes(x = (price),
                      fill = price)) +
  geom_density(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="price", 
       
       caption="Source: App store 7200 (2017)",
       x="price",y = 'Percent',
       fill="price")
# Out:
# plot without title

# %%
ggplot(new_data1, aes(x = factor(price),
                      fill = factor(price))) +
  geom_bar(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="price", 
       
       caption="Source: App store 7200 (2017)",
       x="Price",y = 'Percent',
       fill="Price")
# Out:
# plot without title

# %% [markdown]
# ## 4. 파생변수 생성 및 Y의 변형

# %% [markdown]
# ## 4.1 파생변수 생성
#
# - user_rating_ver : 현재 버전 평균 별점 (mean)
# - rating_count_ver : 현재 버전 별점 횟수 ( N)
#
#
# ---> sum_rate_ver = mean * N

# %%
new_data1$sum_rate_ver = new_data1$rating_count_ver*new_data1$user_rating_ver
new_data2$sum_rate_ver = new_data2$rating_count_ver*new_data2$user_rating_ver

# %% [markdown]
# ## 4.2 Y의 변형
#
# ### Y = user_rating (평균평점)
#
# - min : 0
#
# - max : 5

# %%
#unique(new_data1$user_rating)
#min(new_data1$user_rating)
#max(new_data1$user_rating)

# %%
ggplot(new_data1, aes(x = factor(user_rating),
                      fill = factor(user_rating))) +
  geom_bar(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="user_rating", 
       
       caption="Source: App store 7200 (2017)",
       x="user_rating",y = 'Percent',
       fill="user_rating")
# Out:
# plot without title

# %% [markdown]
# ### 4.2.1 - Z Transformation

# %%
reg_data_1 = new_data1 # game vs nongame
reg_data_2 = new_data2 # game,... and etc

reg_data_1$user_rating_scaled <- scale(new_data1$user_rating)[, 1]
reg_data_2$user_rating_scaled <-scale(new_data2$user_rating)[, 1]

# %%
ggplot(reg_data_1, aes(x = factor(user_rating_scaled),
                      fill = factor(user_rating_scaled))) +
  geom_bar(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="user_rating_scaled", 
       
       caption="Source: App store 7200 (2017)",
       x="user_rating_scaled",y = 'Percent',
       fill="user_rating_scaled")
# Out:
# plot without title

# %%
#str(reg_data_1)
#str(reg_data_2)
drops<-c("user_rating")
reg_data_1=reg_data_1[ , !(names(reg_data_1) %in% drops)]
reg_data_2=reg_data_2[ , !(names(reg_data_2) %in% drops)]

# %% [markdown]
# ### 4.2.2 - 5 classes/ 10classes
#
# - cls_1[prime_genre] = Games, Non_game , cls_1[user_rating] = seq(1,5)
# - cls_2[prime_genre] = Games, Non_game , cls_1[user_rating] = seq(0,5,by=0.5)

# %%
#############################
### classification data ##### 
#############################
cls_1 = new_data1 # 5분류
cls_2 = new_data1 # 10분류

cls_1$user_rating <- cut(cls_1$user_rating, breaks=c(-Inf,1,2,3,4,Inf), 
                   labels=c("1","2","3","4","5"))
cls_1$user_rating = as.ordered(cls_1$user_rating)
cls_2$user_rating = as.ordered(cls_2$user_rating)

levels(cls_1$user_rating)
levels(cls_2$user_rating)
levels(cls_1$prime_genre)
levels(cls_2$prime_genre)
# Out:
# [1] "1" "2" "3" "4" "5"
#  [1] "0"   "1"   "1.5" "2"   "2.5" "3"   "3.5" "4"   "4.5" "5"
# [1] "Games"     "Non_Games"
# [1] "Games"     "Non_Games"

# %%
ggplot(cls_1, aes(x = factor(user_rating),
                       fill = factor(user_rating))) +
  geom_bar(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="5 Levels", 
       
       caption="Source: App store 7200 (2017)",
       x="user_rating",y = 'Percent',
       fill="user_rating")
# Out:
# plot without title

# %%
ggplot(cls_2, aes(x = factor(user_rating),
                  fill = factor(user_rating))) +
  geom_bar(aes(y = (..count..)/sum(..count..))) + 
  scale_y_continuous(labels=percent_format()) +
  labs(title="10 Levels", 
       
       caption="Source: App store 7200 (2017)",
       x="user_rating",y = 'Percent',
       fill="user_rating")
# Out:
# plot without title

# %% [markdown]
# ### 4.2.2 - 5 classes/ 10classes
#
# - cls_3[prime_genre] = 'Education' 'Entertainment' 'Games' 'Photo & Video' 'Utilities' 'etc'
# - cls_3[user_rating] = seq(1,5)
# - cls_4[prime_genre] = 'Education' 'Entertainment' 'Games' 'Photo & Video' 'Utilities' 'etc'
# - cls_4[user_rating] = seq(0,5,by=0.5)

# %%
#############################
### classification data ##### 
#############################
cls_3 = new_data2 # 5분류
cls_4 = new_data2 # 10분류

cls_3$user_rating <- cut(cls_3$user_rating, breaks=c(-Inf,1,2,3,4,Inf), 
                         labels=c("1","2","3","4","5"))
cls_3$user_rating = as.ordered(cls_3$user_rating)
cls_4$user_rating = as.ordered(cls_4$user_rating)
levels(cls_3$user_rating)
levels(cls_4$user_rating)
levels(cls_3$prime_genre)
levels(cls_4$prime_genre)
# Out:
# [1] "1" "2" "3" "4" "5"
#  [1] "0"   "1"   "1.5" "2"   "2.5" "3"   "3.5" "4"   "4.5" "5"
# [1] "Education"     "Entertainment" "Games"         "Photo & Video"
# [5] "Utilities"     "etc"
# [1] "Education"     "Entertainment" "Games"         "Photo & Video"
# [5] "Utilities"     "etc"

# %% [markdown]
# # 5. Train/test split

# %%
# Random sample indexes
train_index <- sample(1:nrow(new_data1), 0.8 * nrow(new_data1))
test_index <- setdiff(1:nrow(new_data1), train_index)
# Build train/test


reg_1_train <- reg_data_1[train_index,]
reg_1_test <- reg_data_1[test_index,]

reg_2_train <- reg_data_2[train_index,]
reg_2_test <- reg_data_2[test_index,]

## game_nongame
cls_1_train <- cls_1[train_index, ]
cls_1_test <- cls_1[test_index, ]

cls_2_train <- cls_2[train_index, ]
cls_2_test <- cls_2[test_index, ]
## game,...,etc
cls_3_train <- cls_3[train_index, ]
cls_3_test <- cls_3[test_index, ]

cls_4_train <- cls_4[train_index, ]
cls_4_test <- cls_4[test_index, ]

# %%
save(reg_1_train, file ='reg_1_train.rda') # game_non
save(reg_1_test, file ='reg_1_test.rda')

save(reg_2_train, file ='reg_2_train.rda') # game,...,etc
save(reg_2_test, file ='reg_2_test.rda')



save(cls_1_train, file ='cls_1_train.rda')
save(cls_1_test, file ='cls_1_test.rda')

save(cls_2_train, file ='cls_2_train.rda')
save(cls_2_test, file ='cls_2_test.rda')

save(cls_3_train, file ='cls_3_train.rda')
save(cls_3_test, file ='cls_3_test.rda')

save(cls_4_train, file ='cls_4_train.rda')
save(cls_4_test, file ='cls_4_test.rda')
